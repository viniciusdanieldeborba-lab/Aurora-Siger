# %% [markdown]
# <a href="https://colab.research.google.com/github/viniciusdanieldeborba-lab/Aurora-Siger/blob/main/RELATORIO_AURORA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RELATORIO AURORA SIGER
# ## ATIVIDADE INTEGRADORA FIAP

# %%
print ("Hello World")
# Out:
# Hello World
